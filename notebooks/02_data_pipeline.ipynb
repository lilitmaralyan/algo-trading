# %%
from algo_trading.data.yahoo import get_historical_data
from datetime import datetime

# %%
candles = get_historical_data(
    symbol="AAPL",
    interval="1wk",
    start=datetime(2026, 1, 1),
    end=datetime(2026, 6, 1)
    )
candles[0]
# Out:
# Candle(symbol='AAPL', timestamp=Timestamp('2026-01-01 00:00:00-0500', tz='America/New_York'), open=271.7550971709494, high=277.32473552681375, low=259.32817380451803, close=259.8471984863281, volume=184147200.0)

# %%
type(candles)
# Out:
# list

# %%
type(candles[0])
# Out:
# algo_trading.models.candle.Candle

# %%
len(candles)
# Out:
# 22

# %%
candles[:3]
# Out:
# [Candle(symbol='AAPL', timestamp=Timestamp('2026-01-01 00:00:00-0500', tz='America/New_York'), open=271.7550971709494, high=277.32473552681375, low=259.32817380451803, close=259.8471984863281, volume=184147200.0),
#  Candle(symbol='AAPL', timestamp=Timestamp('2026-01-08 00:00:00-0500', tz='America/New_York'), open=256.5433549577336, high=261.33447181199796, low=255.22581076872925, close=259.4779052734375, volume=221430300.0),
#  Candle(symbol='AAPL', timestamp=Timestamp('2026-01-15 00:00:00-0500', tz='America/New_York'), open=260.16664283673003, high=260.55593423944316, low=242.96859852637678, close=247.1907501220703, volume=246440600.0)]

# %%
candles[0].timestamp
# Out:
# <bound method _Timestamp.month_name of Timestamp('2026-01-01 00:00:00-0500', tz='America/New_York')>

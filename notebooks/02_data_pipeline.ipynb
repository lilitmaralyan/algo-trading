# %%
from algo_trading.data.yahoo import get_historical_data
from datetime import datetime
# Out:
# /Users/lilitmaralyan/Desktop/algo-trading/src/algo_trading/data/yahoo.py

# %%
candles = get_historical_data(
    symbol="AAPL",
    interval="1wk",
    start=datetime(2026, 1, 1),
    end=datetime(2026, 6, 1)
    )
candles[0]
# Out:
# Candle(symbol='AAPL', timestamp=Timestamp('2026-01-01 00:00:00-0500', tz='America/New_York'), open=np.float64(271.75512908704263), high=np.float64(277.3247680970294), low=np.float64(259.3282042611396), close=np.float64(259.84722900390625), volume=np.float64(184147200.0))

# %%
type(candles)
# Out:
# list

# %%
type(candles[0])
# Out:
# models.candle.Candle

# %%
len(candles)
# Out:
# 22

# %%
candles[:3]
# Out:
# [Candle(symbol='AAPL', timestamp=Timestamp('2026-01-01 00:00:00-0500', tz='America/New_York'), open=np.float64(271.75512908704263), high=np.float64(277.3247680970294), low=np.float64(259.3282042611396), close=np.float64(259.84722900390625), volume=np.float64(184147200.0)),
#  Candle(symbol='AAPL', timestamp=Timestamp('2026-01-08 00:00:00-0500', tz='America/New_York'), open=np.float64(256.5433549577336), high=np.float64(261.33447181199796), low=np.float64(255.22581076872925), close=np.float64(259.4779052734375), volume=np.float64(221430300.0)),
#  Candle(symbol='AAPL', timestamp=Timestamp('2026-01-15 00:00:00-0500', tz='America/New_York'), open=np.float64(260.16664283673003), high=np.float64(260.55593423944316), low=np.float64(242.96859852637678), close=np.float64(247.1907501220703), volume=np.float64(246440600.0))]
